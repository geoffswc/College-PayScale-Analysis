# %%
# using data from: https://www.payscale.com/college-salary-report

# methodology
# https://www.payscale.com/college-salary-report/methodology

# %% [markdown]
# "Best Schools by Major: Since major choice plays an instrumental role in your potential salary, we rank schools based on the earnings of graduates within a major group for Bachelor’s only graduates. Inclusion in this list required that a school-major combination met the same inclusion criteria described above. For this reason, the schools included for each major are a subset of the bachelor’s degree lists."
#
# and
#
# "Additionally, similarly to the overall school rankings, these schools are ranked based on the median mid-career earnings of graduates within a major group. The pay values do not control for job choice, only major and school selection. This is important to keep in mind as graduates for one school may select very different jobs than graduates from another school, even if they share the same major.
#
# Also important to keep in mind is that salaries are grouped into "early" and "mid", where early is 0-5 years of experience and "mid" is 10+ years (this informationis available by clicking the info icon next to early and mid in the report tables).
#
# also
#
# "Salary: Combines base annual salary or hourly wage, bonuses, profit sharing, tips, commissions, overtime, and other forms of cash earnings, as applicable.
#
# Salary does not include equity (stock) compensation, which can be a significant portion of pay for some executive and high-tech jobs. In addition, salary does not include cash value of retirement benefits, or value of other non-cash benefits (e.g. healthcare). Salaries were inflation-adjusted to current year dollars to ensure apples-to-apples comparison over the data collection period."

# %%
import pandas as pd

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('payscale-all-majors-colleges.csv')

# %%
df = df.reset_index()

# %%
# by query
# early salary as a percentage of the highest early salary
# late salary as a percentage of highest late salary

avg_early = pysqldf("""
SELECT major, AVG(early), 
    AVG(
    early / (SELECT MAX(avg_early) FROM (SELECT AVG(early) avg_early FROM df GROUP BY major))
    ) AS as_pct_max
FROM df
GROUP BY major
""")

#avg_early

avg_late = pysqldf("""
SELECT major, AVG(late), 
    AVG(
    late / (SELECT MAX(avg_late) FROM (SELECT AVG(late) avg_late FROM df GROUP BY major))
    ) AS as_pct_max
FROM df
GROUP BY major
""")

#avg_late

pysqldf("""
SELECT
    ae.major, 
    ae.as_pct_max as pct_max_early, 
    al.as_pct_max as pct_max_late
FROM
    avg_early ae
JOIN
    avg_late al
ON
    ae.major = al.major

""")
# Out:
#                         major  pct_max_early  pct_max_late
# 0                         art       0.675873      0.651709
# 1               communication       0.693436      0.748773
# 2            computer-science       0.969080      0.955020
# 3                 engineering       0.981709      0.952594
# 4              health-science       0.791484      0.670402
# 5                  humanities       0.698443      0.719255
# 6                        math       1.000000      1.000000
# 7  physical-and-life-sciences       0.745503      0.783604
# 8             social-sciences       0.700739      0.708938

# %%
# by query
# early salary as a percentage of the highest early salary
# late salary as a percentage of highest late salary

avg_early = pysqldf("""

WITH avg_early AS
(
SELECT major, AVG(early), 
    AVG(
    early / (SELECT MAX(avg_early) FROM (SELECT AVG(early) avg_early FROM df GROUP BY major))
    ) AS as_pct_max
FROM df
GROUP BY major
),

avg_mid AS
(
SELECT major, AVG(late), 
    AVG(
    late / (SELECT MAX(avg_late) FROM (SELECT AVG(late) avg_late FROM df GROUP BY major))
    ) AS as_pct_max
FROM df
GROUP BY major
) 

SELECT
    ae.major, 
    ae.as_pct_max as pct_max_early, 
    am.as_pct_max as pct_max_late
FROM
    avg_early ae
JOIN
    avg_mid am
ON
    ae.major = am.major

""")

# %%
avg_early
# Out:
#                         major  pct_max_early  pct_max_late
# 0                         art       0.675873      0.651709
# 1               communication       0.693436      0.748773
# 2            computer-science       0.969080      0.955020
# 3                 engineering       0.981709      0.952594
# 4              health-science       0.791484      0.670402
# 5                  humanities       0.698443      0.719255
# 6                        math       1.000000      1.000000
# 7  physical-and-life-sciences       0.745503      0.783604
# 8             social-sciences       0.700739      0.708938

# %%
#df.groupby("major").describe()['late']

# %%
#df.groupby("major").describe()['early']

# %%
# let's see if there's a big difference if you only consider the top programs from each field. 
# I'll do this two ways. First, I'll just consider the top 10 for each program.
# then, I'll consider the top 10% for each program (since the number of programs by major varies
# i.e, there are a lot more computer science departments than math departments represented)

# %%
df_top_10_by_major = pysqldf("""
SELECT r.*
FROM
(
    SELECT
        r.*,
        ROW_NUMBER() OVER(PARTITION BY r.major
                          ORDER BY r.late DESC) rn
    FROM df r
) r
WHERE r.rn <= 10
ORDER BY late DESC
""")

# %%
df_top_10_by_major
# Out:
#     level_0  Unnamed: 0  index  \
# 0      2750        2750      0
# 1       525         525      0
# 2       526         526      1
# 3       527         527      2
# 4       528         528      3
# 5       529         529      4
# 6       530         530      5
# 7       531         531      6
# 8       532         532      7
# 9       533         533      8
# 10     1125        1125      0
# 11      534         534      9
# 12     1126        1126      1
# 13     1127        1127      2
# 14     1128        1128      3
# 15     3775        3775      0
# 16     2350        2350      0
# 17     1129        1129      4
# 18     1130        1130      5
# 19     3275        3275      0
# 20     1131        1131      6
# 21     2351        2351      1
# 22     2352        2352      2
# 23     2353        2353      3
# 24     2751        2751      1
# 25     2354        2354      4
# 26     2355        2355      5
# 27     2356        2356      6
# 28     2357        2357      7
# 29     1132        1132      7
# 30     2358        2358      8
# 31     2752        2752      2
# 32     2753        2753      3
# 33     2359        2359      9
# 34     2754        2754      4
# 35     1133        1133      8
# 36     2755        2755      5
# 37     1134        1134      9
# 38     2756        2756      6
# 39     2757        2757      7
# 40     3276        3276      1
# 41     2758        2758      8
# 42     2759        2759      9
# 43     2850        2850      0
# 44     3277        3277      2
# 45     3278        3278      3
# 46     3279        3279      4
# 47        0           0      0
# 48     2851        2851      1
# 49     2852        2852      2
# 50     3280        3280      5
# 51        1           1      1
# 52     3281        3281      6
# 53     3282        3282      7
# 54     3283        3283      8
# 55     2853        2853      3
# 56     1950        1950      0
# 57     2854        2854      4
# 58        2           2      2
# 59     3284        3284      9
# 60     2855        2855      5
# 61     2856        2856      6
# 62        3           3      3
# 63     2857        2857      7
# 64     2858        2858      8
# 65        4           4      4
# 66     2859        2859      9
# 67        5           5      5
# 68     3776        3776      1
# 69     3777        3777      2
# 70        6           6      6
# 71        7           7      7
# 72        8           8      8
# 73        9           9      9
# 74     1951        1951      1
# 75     3778        3778      3
# 76     3779        3779      4
# 77     3780        3780      5
# 78     1952        1952      2
# 79     3781        3781      6
# 80     1953        1953      3
# 81     1954        1954      4
# 82     1955        1955      5
# 83     1956        1956      6
# 84     1957        1957      7
# 85     3782        3782      7
# 86     1958        1958      8
# 87     1959        1959      9
# 88     3783        3783      8
# 89     3784        3784      9
#
#                                                school   early    late  \
# 0                                  Harvard University   96600  205600
# 1                                 Harvey Mudd College  117700  189200
# 2                                 Stanford University  119600  183100
# 3                   University of California-Berkeley  115700  181100
# 4                                  Harvard University  103900  179400
# 5                          Carnegie Mellon University  109200  178300
# 6               Massachusetts Institute of Technology  109300  177200
# 7                                Princeton University  115100  177100
# 8         Columbia University in the City of New York  104300  175400
# 9                                   Dartmouth College  113300  174900
# 10                         University of Pennsylvania   78000  174500
# 11                                    Yale University  115400  174300
# 12                                 Colgate University   75200  169800
# 13                                    Yale University   80900  167800
# 14              Massachusetts Institute of Technology   86200  166800
# 15                                 Harvard University  115200  164000
# 16              Massachusetts Institute of Technology   94800  163800
# 17                        United States Naval Academy   88900  163300
# 18                               Princeton University   76900  163200
# 19                                Harvey Mudd College   92100  163100
# 20                                 Cornell University   73600  163100
# 21                                   Marietta College  100800  162100
# 22        Columbia University in the City of New York   85100  162100
# 23                                University of Tulsa   87400  162000
# 24                         Carnegie Mellon University  101300  161800
# 25                        United States Naval Academy   90200  161300
# 26                                 Harvard University   89500  160700
# 27                 University of California-San Diego   82100  160200
# 28                             Santa Clara University   88500  159900
# 29                                 Harvard University   81800  159600
# 30                                Stanford University   94000  159400
# 31              Massachusetts Institute of Technology   97700  158900
# 32                  University of California-Berkeley   91000  158500
# 33                     United States Military Academy   91600  158300
# 34                 University of California-San Diego   78600  158300
# 35                                   Williams College   76800  158000
# 36                 University of Virginia-Main Campus   85900  154400
# 37                      Washington and Lee University   72200  154000
# 38                        United States Naval Academy   90800  153600
# 39                                New York University   84000  150700
# 40                                    Yale University   81400  149100
# 41  Virginia Polytechnic Institute and State Unive...   73300  149000
# 42                              Vanderbilt University   82800  148900
# 43                  University of California-Berkeley   68200  148300
# 44                                 Harvard University   79300  147500
# 45                               Princeton University   76300  147000
# 46              Massachusetts Institute of Technology   78800  146900
# 47                                    Yale University   70700  145800
# 48                             Santa Clara University   68700  143800
# 49                                Stanford University   73100  143600
# 50                                  Dartmouth College   76000  142200
# 51                               Princeton University   74300  141500
# 52                                Stanford University   73800  141400
# 53                 California Institute of Technology   77100  140300
# 54                  University of California-Berkeley   71000  139500
# 55                         University of Pennsylvania   69900  139400
# 56                                Stanford University   85200  138700
# 57                              Vanderbilt University   68000  138100
# 58                                 Colgate University   71500  138000
# 59                           Colorado School of Mines   72600  137400
# 60             University of California-Santa Barbara   60800  134300
# 61                                  Boston University   59300  133900
# 62                                  Dartmouth College   71100  132500
# 63                             Wake Forest University   61400  132000
# 64                     University of California-Davis   62500  132000
# 65                           University of Notre Dame   63700  130900
# 66                 University of Virginia-Main Campus   56600  130800
# 67        Columbia University in the City of New York   68800  130500
# 68      Albany College of Pharmacy and HealthSciences   81900  130400
# 69                 University of California-San Diego   66000  128600
# 70                                 Cornell University   70400  128600
# 71                                     Boston College   63400  127400
# 72                                 Harvard University   71400  127000
# 73                         University of Pennsylvania   69600  126300
# 74                                  Dartmouth College   65600  125700
# 75                  University of California-Berkeley   78500  123500
# 76                         University of the Sciences   74700  122800
# 77                     St. John's University-New York   73500  121700
# 78                                     The New School   61600  120000
# 79                                   MCPHS University   71300  120000
# 80                                 Cornell University   62100  119200
# 81                                 Colgate University   65500  117400
# 82                           University of Notre Dame   63900  116300
# 83                                   Brown University   60600  113700
# 84        Georgia Institute of Technology-Main Campus   63700  113100
# 85                                   Drake University   68800  112200
# 86                         University of Pennsylvania   60500  111800
# 87                       Art Center College of Design   67400  111800
# 88                                  Butler University   71000  111800
# 89                     College of Mount Saint Vincent   76700  111700
#
#                          major  rn
# 0                         math   1
# 1             computer-science   1
# 2             computer-science   2
# 3             computer-science   3
# 4             computer-science   4
# 5             computer-science   5
# 6             computer-science   6
# 7             computer-science   7
# 8             computer-science   8
# 9             computer-science   9
# 10             social-sciences   1
# 11            computer-science  10
# 12             social-sciences   2
# 13             social-sciences   3
# 14             social-sciences   4
# 15              health-science   1
# 16                 engineering   1
# 17             social-sciences   5
# 18             social-sciences   6
# 19  physical-and-life-sciences   1
# 20             social-sciences   7
# 21                 engineering   2
# 22                 engineering   3
# 23                 engineering   4
# 24                        math   2
# 25                 engineering   5
# 26                 engineering   6
# 27                 engineering   7
# 28                 engineering   8
# 29             social-sciences   8
# 30                 engineering   9
# 31                        math   3
# 32                        math   4
# 33                 engineering  10
# 34                        math   5
# 35             social-sciences   9
# 36                        math   6
# 37             social-sciences  10
# 38                        math   7
# 39                        math   8
# 40  physical-and-life-sciences   2
# 41                        math   9
# 42                        math  10
# 43               communication   1
# 44  physical-and-life-sciences   3
# 45  physical-and-life-sciences   4
# 46  physical-and-life-sciences   5
# 47                  humanities   1
# 48               communication   2
# 49               communication   3
# 50  physical-and-life-sciences   6
# 51                  humanities   2
# 52  physical-and-life-sciences   7
# 53  physical-and-life-sciences   8
# 54  physical-and-life-sciences   9
# 55               communication   4
# 56                         art   1
# 57               communication   5
# 58                  humanities   3
# 59  physical-and-life-sciences  10
# 60               communication   6
# 61               communication   7
# 62                  humanities   4
# 63               communication   8
# 64               communication   9
# 65                  humanities   5
# 66               communication  10
# 67                  humanities   6
# 68              health-science   2
# 69              health-science   3
# 70                  humanities   7
# 71                  humanities   8
# 72                  humanities   9
# 73                  humanities  10
# 74                         art   2
# 75              health-science   4
# 76              health-science   5
# 77              health-science   6
# 78                         art   3
# 79              health-science   7
# 80                         art   4
# 81                         art   5
# 82                         art   6
# 83                         art   7
# 84                         art   8
# 85              health-science   8
# 86                         art   9
# 87                         art  10
# 88              health-science   9
# 89              health-science  10

# %%
# by query
# early salary as a percentage of the highest early salary
# late salary as a percentage of highest late salary

avg_early = pysqldf("""
SELECT major, AVG(early), 
    AVG(
    early / (SELECT MAX(avg_early) FROM (SELECT AVG(early) avg_early FROM df_top_10_by_major GROUP BY major))
    ) AS as_pct_max
FROM df_top_10_by_major
GROUP BY major
""")

#avg_early

avg_late = pysqldf("""
SELECT major, AVG(late), 
    AVG(
    late / (SELECT MAX(avg_late) FROM (SELECT AVG(late) avg_late FROM df_top_10_by_major GROUP BY major))
    ) AS as_pct_max
FROM df_top_10_by_major
GROUP BY major
""")

#avg_late

pysqldf("""
SELECT
    ae.major, 
    ae.as_pct_max as pct_max_early, 
    al.as_pct_max as pct_max_late
FROM
    avg_early ae
JOIN
    avg_late al
ON
    ae.major = al.major

""")
# Out:
#                         major  pct_max_early  pct_max_late
# 0                         art       0.583979      0.663520
# 1               communication       0.577214      0.768827
# 2            computer-science       1.000000      1.000000
# 3                 engineering       0.804628      0.899330
# 4              health-science       0.692123      0.696480
# 5                  humanities       0.618514      0.742179
# 6                        math       0.785047      0.893687
# 7  physical-and-life-sciences       0.692835      0.812514
# 8             social-sciences       0.703605      0.916257

# %%
# by query
# early salary as a percentage of the highest early salary
# late salary as a percentage of highest late salary
# now doing this by percent rather than by number

# %%
# easier to do this with pandas

# %%
a = 0.1

df_early_t10p = (df.groupby('major',group_keys=False)
        .apply(lambda x: x.nlargest(int(len(x) * a), 'early')))

df_late_t10p = (df.groupby('major',group_keys=False)
        .apply(lambda x: x.nlargest(int(len(x) * a), 'late')))

# %%
df_early_t10p.groupby('major').describe()
# Out:
#                            level_0                                           \
#                              count         mean        std     min      25%
# major
# art                           40.0  1983.175000  30.394743  1950.0  1959.75
# communication                 42.0  2878.833333  25.888991  2850.0  2861.25
# computer-science              60.0   565.083333  33.550514   525.0   539.75
# engineering                   40.0  2378.900000  24.459071  2350.0  2359.75
# health-science                65.0  3827.907692  47.491355  3775.0  3792.00
# humanities                    52.0    34.288462  32.468589     0.0    12.75
# math                          10.0  2756.800000   6.425643  2750.0  2752.25
# physical-and-life-sciences    50.0  3303.940000  21.548626  3275.0  3287.25
# social-sciences               82.0  1177.292683  51.833420  1125.0  1145.25
#
#                                                     Unnamed: 0               \
#                                50%      75%     max      count         mean
# major
# art                         1974.0  1993.25  2056.0       40.0  1983.175000
# communication               2872.5  2890.00  2959.0       42.0  2878.833333
# computer-science             559.5   578.25   672.0       60.0   565.083333
# engineering                 2373.5  2392.25  2447.0       40.0  2378.900000
# health-science              3811.0  3857.00  3973.0       65.0  3827.907692
# humanities                    26.5    45.50   162.0       52.0    34.288462
# math                        2755.5  2759.25  2771.0       10.0  2756.800000
# physical-and-life-sciences  3299.5  3316.75  3360.0       50.0  3303.940000
# social-sciences             1166.5  1189.75  1470.0       82.0  1177.292683
#
#                             ...    early            late                 \
#                             ...      75%       max count           mean
# major                       ...
# art                         ...  63100.0   85200.0  40.0  106390.000000
# communication               ...  63300.0   73100.0  42.0  122435.714286
# computer-science            ...  99500.0  119600.0  60.0  157435.000000
# engineering                 ...  88125.0  100800.0  40.0  150420.000000
# health-science              ...  74700.0  115200.0  65.0  104398.461538
# humanities                  ...  67300.0   78900.0  52.0  118994.230769
# math                        ...  95200.0  101300.0  10.0  158030.000000
# physical-and-life-sciences  ...  72250.0   92100.0  50.0  127802.000000
# social-sciences             ...  73250.0   88900.0  82.0  135480.487805
#
#                                                                         \
#                                      std       min       25%       50%
# major
# art                          9746.999538   91900.0  100525.0  105800.0
# communication               10990.102452  104300.0  114300.0  119200.0
# computer-science            12884.688390  133900.0  149000.0  154700.0
# engineering                  8219.526470  134100.0  144475.0  149050.0
# health-science              11166.824363   90500.0   97200.0  101900.0
# humanities                   9658.632499   97600.0  113025.0  118150.0
# math                        17802.374998  141900.0  149275.0  154000.0
# physical-and-life-sciences  11427.723004  111700.0  118100.0  126200.0
# social-sciences             16102.736820   90700.0  125625.0  132850.0
#
#
#                                  75%       max
# major
# art                         111725.0  138700.0
# communication               129700.0  148300.0
# computer-science            165750.0  189200.0
# engineering                 157775.0  163800.0
# health-science              109700.0  164000.0
# humanities                  125800.0  145800.0
# math                        158800.0  205600.0
# physical-and-life-sciences  135075.0  163100.0
# social-sciences             145325.0  174500.0
#
# [9 rows x 40 columns]

# %%
avg_early = pysqldf("""
SELECT major, AVG(early), 
    AVG(
    early / (SELECT MAX(avg_early) FROM (SELECT AVG(early) avg_early FROM df_early_t10p GROUP BY major))
    ) AS as_pct_max
FROM df_early_t10p
GROUP BY major
""")

#avg_early

avg_late = pysqldf("""
SELECT major, AVG(late), 
    AVG(
    late / (SELECT MAX(avg_late) FROM (SELECT AVG(late) avg_late FROM df_late_t10p GROUP BY major))
    ) AS as_pct_max
FROM df_late_t10p
GROUP BY major
""")

#avg_late

pysqldf("""
SELECT
    ae.major, 
    ae.as_pct_max as pct_max_early, 
    al.as_pct_max as pct_max_late
FROM
    avg_early ae
JOIN
    avg_late al
ON
    ae.major = al.major

""")
# Out:
#                         major  pct_max_early  pct_max_late
# 0                         art       0.641649      0.681925
# 1               communication       0.640847      0.777050
# 2            computer-science       1.000000      0.999031
# 3                 engineering       0.895911      0.954101
# 4              health-science       0.757244      0.665692
# 5                  humanities       0.676717      0.753675
# 6                        math       0.951914      1.000000
# 7  physical-and-life-sciences       0.713982      0.803726
# 8             social-sciences       0.722089      0.860466
